x_2 = [0, 0.020202, 0.040404, 0.0606061, 0.0808081, 0.10101, 0.121212, 0.141414, 0.161616, 0.181818, 0.20202, 0.222222, 0.242424, 0.262626, 0.282828, 0.30303, 0.323232, 0.343434, 0.363636, 0.383838, 0.40404, 0.424242, 0.444444, 0.464646, 0.484848, 0.505051, 0.525253, 0.545455, 0.565657, 0.585859, 0.606061, 0.626263, 0.646465, 0.666667, 0.686869, 0.707071, 0.727273, 0.747475, 0.767677, 0.787879, 0.808081, 0.828283, 0.848485, 0.868687, 0.888889, 0.909091, 0.929293, 0.949495, 0.969697, 0.989899, 1.0101, 1.0303, 1.05051, 1.07071, 1.09091, 1.11111, 1.13131, 1.15152, 1.17172, 1.19192, 1.21212, 1.23232, 1.25253, 1.27273, 1.29293, 1.31313, 1.33333, 1.35354, 1.37374, 1.39394, 1.41414, 1.43434, 1.45455, 1.47475, 1.49495, 1.51515, 1.53535, 1.55556, 1.57576, 1.59596, 1.61616, 1.63636, 1.65657, 1.67677, 1.69697, 1.71717, 1.73737, 1.75758, 1.77778, 1.79798, 1.81818, 1.83838, 1.85859, 1.87879, 1.89899, 1.91919, 1.93939, 1.9596, 1.9798, 2]
y_2 = [1, 1.00549, 1.01219, 1.02009, 1.0292, 1.03951, 1.05103, 1.06375, 1.07768, 1.09281, 1.10914, 1.12669, 1.14543, 1.16539, 1.18654, 1.2089, 1.23247, 1.25724, 1.28322, 1.3104, 1.33879, 1.36838, 1.39918, 1.43118, 1.46438, 1.4988, 1.53441, 1.57123, 1.60926, 1.64849, 1.68893, 1.73057, 1.77342, 1.81747, 1.86272, 1.90918, 1.95685, 2.00572, 2.0558, 2.10708, 2.15957, 2.21326, 2.26815, 2.32425, 2.38156, 2.44007, 2.49979, 2.56071, 2.62283, 2.68616, 2.7507, 2.81644, 2.88339, 2.95154, 3.02089, 3.09145, 3.16322, 3.23619, 3.31037, 3.38575, 3.46233, 3.54012, 3.61912, 3.69932, 3.78073, 3.86334, 3.94715, 4.03217, 4.1184, 4.20583, 4.29446, 4.3843, 4.47535, 4.5676, 4.66106, 4.75572, 4.85158, 4.94865, 5.04693, 5.14641, 5.24709, 5.34898, 5.45208, 5.55638, 5.66188, 5.76859, 5.87651, 5.98563, 6.09595, 6.20748, 6.32022, 6.43416, 6.5493, 6.66565, 6.78321, 6.90197, 7.02193, 7.1431, 7.26548, 7.38906]

plt.grid()
plt.plot(x_2, y_2, label = 'interpolated')
plt.plot(x_2, np.exp(x_2), label = 'genuine')
plt.xlabel(r'$x$', loc = 'right')
plt.ylabel(r'$y$', rotation = 0, loc = 'top')
plt.legend()
plt.title('N = 3')
plt.show()

# %%
lengths = [2, 1, 0.5, 0.25, 0.125, 0.0625]
errors_3 = [0.213456, 0.0144207, 0.00133928, 0.000144695, 1.68267e-05, 2.02909e-06]
errors_4 = [0.0271413, 0.00092402, 4.297e-05, 2.32139e-06, 1.34962e-07, 8.1365e-09]
errors_5 = [0.00305648, 5.26571e-05, 1.22995e-06, 3.32862e-08, 9.6843e-10, 2.9204e-11]
errors_3_1 = [0.153496, 0.00986555, 0.000892973, 9.52264e-05, 1.10015e-05, 1.32229e-06]
errors_4_1 = [0.0180952, 0.000600007, 2.75427e-05, 1.47842e-06, 8.56781e-08, 5.15709e-09]
errors_5_1 = [0.00173888, 2.94548e-05, 6.82559e-07, 1.84015e-08, 5.34359e-10, 1.60989e-11]
plt.grid()
plt.plot(lengths, errors_3, label = 'Evenly distributed nodes, N = 3')
plt.plot(lengths, errors_4, label = 'Evenly distributed nodes, N = 4')
plt.plot(lengths, errors_5, label = 'Evenly distributed nodes, N = 5')
plt.plot(lengths, errors_3_1, label = 'Chebyshev nodes, N = 3')
plt.plot(lengths, errors_4_1, label = 'Chebyshev nodes, N = 4')
plt.plot(lengths, errors_5_1, label = 'Chebyshev nodes, N = 5')
plt.xlabel(r'segment length', loc = 'right')
plt.ylabel(r'error', rotation = 0, loc = 'top')
plt.legend()
plt.show()

# %%
lengths = [2, 1, 0.5, 0.25, 0.125, 0.0625]
errors_3 = [0.213456, 0.0144207, 0.00133928, 0.000144695, 1.68267e-05, 2.02909e-06]
errors_4 = [0.0271413, 0.00092402, 4.297e-05, 2.32139e-06, 1.34962e-07, 8.1365e-09]
errors_5 = [0.00305648, 5.26571e-05, 1.22995e-06, 3.32862e-08, 9.6843e-10, 2.9204e-11]
errors_3_1 = [0.153496, 0.00986555, 0.000892973, 9.52264e-05, 1.10015e-05, 1.32229e-06]
errors_4_1 = [0.0180952, 0.000600007, 2.75427e-05, 1.47842e-06, 8.56781e-08, 5.15709e-09]
errors_5_1 = [0.00173888, 2.94548e-05, 6.82559e-07, 1.84015e-08, 5.34359e-10, 1.60989e-11]
plt.grid()
plt.plot(np.log(lengths), np.log(errors_3), label = 'Evenly distributed nodes, N = 3')
plt.plot(np.log(lengths), np.log(errors_4), label = 'Evenly distributed nodes, N = 4')
plt.plot(np.log(lengths), np.log(errors_5), label = 'Evenly distributed nodes, N = 5')
plt.plot(np.log(lengths), np.log(errors_3_1), label = 'Chebyshev nodes, N = 3')
plt.plot(np.log(lengths), np.log(errors_4_1), label = 'Chebyshev nodes, N = 4')
plt.plot(np.log(lengths), np.log(errors_5_1), label = 'Chebyshev nodes, N = 5')
plt.xlabel(r'log(segment length)', loc = 'right')
plt.ylabel(r'log(error)', rotation = 0, loc = 'top')
plt.legend()
plt.show()
