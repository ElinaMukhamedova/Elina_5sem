# %%
import numpy as np
import matplotlib.pyplot as plt
x0_1 = [0, -2.30259, -4.60517, -6.90776, -9.21034, -11.5129, -13.8155, -16.1181, -18.4207, -20.7233, -23.0259, -25.3284, -27.631, -29.9336, -32.2362, -34.5388]
y0_1 = [0.930765, -7.17291, -14.1898, -21.1097, -25.3213, -22.2918, -21.7472, -18.3639, -17.0898, -13.9535, -11.6561, -8.92909, -6.24867, -4.58206, -2.37213, 0.824929]

plt.grid()
plt.plot(x0_1, y0_1, '.')
plt.xlabel(r'$\ln{h}$', loc = 'right')
plt.ylabel(r'$\ln{error}$', rotation = 0, loc = 'top')
plt.title('N = 3')

x1_1 = [0, -2.30259, -4.60517, -6.90776]
y1_1 = [0.930765, -7.17291, -14.1898, -21.1097]
p,v = np.polyfit(x1_1, y1_1, deg=1, cov=True)
xp = np.linspace(-7, 0, 100)
p_f = np.poly1d(p)
print (p)
print (v)
plt.plot(xp, p_f(xp), '-')
# Out:
# [3.17635415 0.58533481]
# [[0.00753143 0.02601267]
#  [0.02601267 0.13975828]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x0_2 = [0, -2.30259, -4.60517, -6.90776, -9.21034, -11.5129, -13.8155, -16.1181, -18.4207, -20.7233, -23.0259, -25.3284, -27.631, -29.9336, -32.2362, -34.5388]
y0_2 = [1.2201, -9.65152, -19.0135, -28.5786, -24.8314, -23.11, -20.6672, -17.0965, -16.3099, -12.7936, -11.1491, -8.67604, -5.43198, -4.78899, -2.64817, -1.26685]

plt.grid()
plt.plot(x0_2, y0_2, '.')
plt.xlabel(r'$\ln{h}$', loc = 'right')
plt.ylabel(r'$\ln{error}$', rotation = 0, loc = 'top')
plt.title('N = 4')

x1_2 = [0, -2.30259, -4.60517]
y1_2 = [1.2201, -9.65152, -19.0135]
p,v = np.polyfit(x1_2, y1_2, deg=1, cov=True)
xp = np.linspace(-7, 0, 100)
p_f = np.poly1d(p)
print (p)
print (v)
plt.plot(xp, p_f(xp), '-')
# Out:
# [4.39367083 0.9685012 ]
# [[0.03581863 0.08247549]
#  [0.08247549 0.31651142]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x0_3 = [0, -2.30259, -4.60517, -6.90776, -9.21034, -11.5129, -13.8155, -16.1181, -18.4207, -20.7233, -23.0259, -25.3284, -27.631, -29.9336, -32.2362, -34.5388]
y0_3 = [1.55935, -12.0884, -23.7864, -27.2724, -25.4307, -21.3205, -21.2816, -18.1297, -18.7978, -13.8252, -11.6561, -9.05146, -5.55034, -7.66668, -2.2917, 1.31351]
plt.grid()
plt.plot(x0_3, y0_3, '.')
plt.xlabel(r'$\ln{h}$', loc = 'right')
plt.ylabel(r'$\ln{error}$', rotation = 0, loc = 'top')
plt.title('N = 5')

x1_3 = [0, -2.30259, -4.60517]
y1_3 = [1.55935, -12.0884, -23.7864]
p,v = np.polyfit(x1_3, y1_3, deg=1, cov=True)
xp = np.linspace(-5, 0, 100)
p_f = np.poly1d(p)
print (p)
print (v)
plt.plot(xp, p_f(xp), '-')
# Out:
# [5.50376021 1.23440155]
# [[0.05974764 0.13757412]
#  [0.13757412 0.52796024]]

# %%
import numpy as np
import matplotlib.pyplot as plt
y0_4 = [0.722881, -4.62809, -9.30145, -13.9134, -18.5191, -23.9664, -21.7472, -18.0624, -16.3099, -13.5169, -12.2363, -11.4729, -6.53983, -5.22299, -7.66668, -0.631642]
x0_4 = [0, -2.30259, -4.60517, -6.90776, -9.21034, -11.5129, -13.8155, -16.1181, -18.4207, -20.7233, -23.0259, -25.3284, -27.631, -29.9336, -32.2362, -34.5388]
plt.grid()
plt.plot(x0_4, y0_4, '.')
plt.xlabel(r'$\ln{h}$', loc = 'right')
plt.ylabel(r'$\ln{error}$', rotation = 0, loc = 'top')
plt.title('N = 2')

x1_4 = [0, -2.30259, -4.60517, -6.90776, -9.21034]
y1_4 = [0.722881, -4.62809, -9.30145, -13.9134, -18.5191]
p,v = np.polyfit(x1_4, y1_4, deg=1, cov=True)
xp = np.linspace(-10, 0, 100)
p_f = np.poly1d(p)
print (p)
print (v)
plt.plot(xp, p_f(xp), '-')
# Out:
# [2.07459323 0.42602687]
# [[0.00139323 0.00641607]
#  [0.00641607 0.04432061]]
