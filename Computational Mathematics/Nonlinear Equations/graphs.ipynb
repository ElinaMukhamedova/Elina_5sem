# %%
import numpy as np
import matplotlib.pyplot as plt
log10_error1 = [-1.94311, -5.27552, -11.9428]
log10_error2 = [-1.46955, -3.97144, -8.97934]
log10_error3 = [-0.50991, -1.62534, -3.80581, -8.16314]
log10_error4 = [0.369527, -1.58247, -3.55882, -7.52074, -15.3525]
plt.grid()
plt.plot([1, 2, 3], log10_error1, label = "ecc = 0.1")
plt.plot([1, 2, 3], log10_error2, label = "ecc = 0.2")
plt.plot([1, 2, 3, 4], log10_error3, label = "ecc = 0.5")
plt.plot([1, 2, 3, 4, 5], log10_error4, label = "ecc = 0.8")
plt.xlabel(r'iteration', loc = 'right')
plt.ylabel(r'log10(error)', rotation = 0, loc = 'top')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
log10_error = [-1.19432, -1.32728, -1.47921, -1.58342, -1.73571, -1.85493, -2.00706, -2.11803, -2.27021, -2.38557, -2.53778, -2.65083, -2.80292, -2.91707, -3.06942, -3.18324, -3.33509, -3.44859, -3.60138, -3.71598, -3.86701, -3.97932, -4.13359, -4.25029, -4.39855, -4.50713, -4.66636, -4.7902, -4.92874, -5.0252, -5.2004, -5.35025, -5.45268, -5.51289, -5.7321, -5.99411, -5.93954, -5.92097, -6.19232]
plt.grid()
plt.plot(np.linspace(0, 38, 39), log10_error)
plt.xlabel(r'iteration', loc = 'right')
plt.ylabel(r'log10(error)', rotation = 0, loc = 'top')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
